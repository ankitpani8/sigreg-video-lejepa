# %% [markdown]
# # sigreg-video-lejepa — Colab Pretraining Notebook
#
# This notebook runs on Google Colab Pro. It:
# 1. Mounts your Drive (where data + checkpoints live)
# 2. Pulls the latest code from GitHub
# 3. Installs deps
# 4. Runs pretraining via Hydra config
# 5. Saves checkpoints back to Drive
#
# **Workflow:** edit code locally in VS Code → push to GitHub → pull in Colab → train → checkpoints sync to Drive → analyze locally.

# %% [markdown]
# ## 1. Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
PROJECT_ROOT = '/content/drive/MyDrive/sigreg-video-lejepa-workspace'
os.makedirs(PROJECT_ROOT, exist_ok=True)
os.chdir(PROJECT_ROOT)
print(f'Working directory: {os.getcwd()}')

# %% [markdown]
# ## 2. Clone or pull the repo
# First run: clones. Subsequent runs: pulls latest.

# %%
import os
REPO_DIR = os.path.join(PROJECT_ROOT, 'sigreg-video-lejepa')

if not os.path.exists(REPO_DIR):
    # !git clone https://github.com/ankitpani8/sigreg-video-lejepa.git
else:
    # %cd {REPO_DIR}
    # !git pull origin main

# %cd {REPO_DIR}
# !git log --oneline -5

# %% [markdown]
# ## 3. Install dependencies

# %%
# !pip install -q uv
# !uv pip install --system -e '.[dev]'

# %% [markdown]
# ## 4. GPU check

# %%
import torch
print(f'CUDA available: {torch.cuda.is_available()}')
print(f'GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else "none"}')
print(f'PyTorch: {torch.__version__}')

# %% [markdown]
# ## 5. wandb login
# Get key from https://wandb.ai/authorize

# %%
import wandb
wandb.login()

# %% [markdown]
# ## 6. Run pretraining
# Will be added once Phase 0 smoke test is in place. Placeholder below.

# %%
# Placeholder — Claude Code will fill this in once scripts/pretrain.py exists.
# !python scripts/pretrain.py experiment=ucf101_vit_tiny
